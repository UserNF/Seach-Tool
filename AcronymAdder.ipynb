# %%
from tkinter import*
f = input("HI")
match f:
    case "FCU":
        a = "fan coil unit"
    case "UH":
        a = "Unit Heater"
    case "EF":
        a = "Exhaust Fan"
    case _:
        a = "Invalid Input"
print(a)
root = Tk()
root.title('JCI Search')
root.iconbitmap('C:/Users/campb/Desktop/Coding Projects/Definition Logger/JCI Logo.ico')
root.geometry("500x500")

# Create a label
my_label = Label(root, text =a, font = "Arial 20", bg = "blue")
my_label.pack(pady=20)

# Create an entry
my_entry = Entry(root, font=("Helvetica", 20))
my_entry.pack()

# Create a listbox
my_list = Listbox(root, width=50)
my_list.pack(pady=40)

#myLabel.pack(side="bottom")
root.mainloop()
# Out:
# HI d
# Invalid Input

# %%
from tkinter import *
from PIL import ImageTk, Image
import tkinter as ttk

# A should get what is in the search bar
a = "FCU"
root = Tk()
root.title('JCI Search')
root.iconbitmap('JCI Logo.ico')
root.geometry("500x500")

# Create a label
my_label = Label(root, text = "Search Acronyms", font = "Arial 20")
my_label.pack(pady=20)

# Create an entry
my_entry = Entry(root, font=("Helvetica", 20))
my_entry.pack()

my_entry.bbox

# Create function to check entry vs list
def check(e):
    a = my_entry.get()
    match a.lower():
        case "jci":
            a = "johnson controls international:"+"\n"+"A smart buildings company"
                 
        case "fcu":
            a = "fan coil unit"
        case "uh":
            a = "Unit Heater"
        case "ef":
            a = "Exhaust Fan"
        case _:
            a = "Invalid Input"
    my_list.delete(END)
    my_list.insert(END, a)



# Create a listbox
my_list = Listbox(root, width=50)
my_list.pack(pady=40)

# Insert
#my_list.insert(END, a)

# Create binding on the entry box call a function if release the key
my_entry.bind("<Key-Return>", check)

#
searchIcon = PhotoImage(file = 'Magnifying Glass.png')
label = ttk.Label(root, image =  searchIcon)
PhotoImage(file = 'Magnifying Glass.png')

d=my_entry.get()



isActive = False
def leave(e):
    isActive = True
    label.place(x = 32232, y=12323)
        
def stay(e):
    if( d==""):
        print(d)
        label.place(x=102, y=82.75)


    
#my_entry.bind("<Leave>", stay)
my_entry.bind("<Enter>", leave)


#my_entry.bind("<Leave>", stay)
    

label.place(x=102, y=82.75)


#myLabel.pack(side="bottom")
root.mainloop()

# %%
definitions = {
    "fcu": "Fan Coil Unit (FCU)",
    "ef": "Exhaust Fan (EF)",
    "uh": "unit heater (UH)"
}

# Sample sentence
sentence = "I need the FCU to control temperature. Also the ef would be useful for the building."

#Get rid of periods so that every word is read

sentence = sentence.replace(".", "")

# Split the sentence into words
words = sentence.split()

# Replace words with their definitions by checking if each word in the sentence matches the words to compaer it to
new_sentence = ' '.join([definitions.get(word.lower(), word) for word in words])

print(new_sentence)
# Out:
# I need the Fan Coil Unit (FCU) to control temperature Also the Exhaust Fan (EF) would be useful for the building

# %%
from tkinter import *
from PIL import ImageTk, Image
import tkinter as ttk

# A should get what is in the search bar
a = "FCU"
root = Tk()
root.title('JCI Search')
root.iconbitmap('JCI Logo.ico')
root.geometry("500x500")

# Create a label
my_label = Label(root, text = "Search Acronyms", font = "Arial 20")
my_label.pack(pady=20)

# Create an entry
my_entry = Entry(root, font=("Helvetica", 20))
my_entry.pack()

my_entry.bbox

# Create function to check entry vs list
def check(e):
    a = my_entry.get()
    definitions = {
    "fcu": "Fan Coil Unit (FCU)",
    "ef": "Exhaust Fan (EF)",
    "uh": "unit heater (UH)"
    }

    summaries = {
        "fcu": "FCU was chose\n",
        "ef": "EF chosen\n"
    }
    
    # Sample sentence
    a = a.replace(".", "")
    
    # Split the sentence into words
    words = a.split()
    
    # Replace words with their definitions
    new_sentence = ' '.join([definitions.get(word.lower(), word.lower()) for word in words])
    my_list.delete(END)
    my_list.insert(END, new_sentence)

    new_summ = ' '.join([summaries.get(s.lower(), s) for s in words])
   
    m.delete(END)
    m.insert(END, new_summ)



# Create a listbox
m = Listbox(root, font=("Helvetica", 10, "bold"), width=50, height=5)
my_list = Listbox(root, font=("Helvetica", 10, "bold"), width=50, height=70)
m.pack(pady=40)
my_list.pack(pady=40)

# Insert
#my_list.insert(END, a)

# Create binding on the entry box call a function if release the key
my_entry.bind("<Key-Return>", check)

#
searchIcon = PhotoImage(file = 'Magnifying Glass.png')
label = ttk.Label(root, image =  searchIcon)
PhotoImage(file = 'Magnifying Glass.png')

d=my_entry.get()



isActive = False
def leave(e):
    isActive = True
    label.place(x = 32232, y=12323)
        
def stay(e):
    if( d==""):
        print(d)
        label.place(x=102, y=82.75)


    
#my_entry.bind("<Leave>", stay)
my_entry.bind("<Enter>", leave)


#my_entry.bind("<Leave>", stay)
    

label.place(x=102, y=82.75)


#myLabel.pack(side="bottom")
root.mainloop()

# %%
from tkinter import *
from PIL import ImageTk, Image
import tkinter as ttk
from tkinter import font

# A should get what is in the search bar
root = Tk()
root.title('JCI Search')
root.iconbitmap('JCI Logo.ico')
root.geometry("500x500")

# Create a label
my_label = Label(root, text = "Search Acronyms", font = "Arial 20")
my_label.pack(pady=20)

# Create an entrybox
my_entry = Entry(root, font=("Helvetica", 20))

my_entry.grid_size()
my_entry.pack()

my_entry.bbox

# Create function to check entry vs list
def check(e):
    a = my_entry.get()
    definitions = {
    "fcu": "Fan Coil Unit (FCU)",
    "ef": "Exhaust Fan (EF)",
    "uh": "Unit Heater (UH)",
    "dhw": "Domestic Hot Water System (DHW)",
    "sump": "Unknown (SUMP)",
    "misc": "Unknwon (MISC)"
    }

    summaries = {
        "fcu": 
        "Fan Coil Unit             (FCU): Small terminal unit that uses a heat exchanger and a fan to generate heating or cooling for a space.",
        "ef": 
        "Exhaust Fan               (EF): Removes unpleasant odors like steam or smoke from rooms and reduces mold.",
        "uh":
        "Unit Heater               (UH):  A unit heater has a heating element, a blower fan, and a heat exchanger that is designed to warm a space.",
        "dhw":
        "Domestic Hot Water System (DHW): Delivers hot water to people at sinks, tubs, and other areas that humans interact.",
        "sump":
        "Unknown                  (SUMP): DEF",
        "misc":
        "Unknwon                  (MISC): DEF"
        
    }
    
    # Sample sentence
    a = a.replace(".", "")
    
    # Split the sentence into words
    words = a.split()
    
    # Replace words with their definitions
    new_sentence = ' '.join([definitions.get(word.lower(), word) for word in words])
    my_list.delete(0,END)
    my_list.insert(END, "TRANSLATIONS")
    my_list.insert(END, new_sentence)
    my_list.insert(END, "")
    my_list.insert(END, "SUMMARIES")

    my_set = []
    # feed all entries to a string that stores the entries and insert that strsing into the
    for i in words:
        for j in summaries:
            if(i.lower() == j and j not in my_set):
                my_list.insert(END, summaries.get(j, j))
                my_set.append(j)
    #new_summary = ' '.join([summaries.get(s.lower(), s) for s in words])



# Create a Translator
my_list = Listbox(root, font=("Helvetica", 10, "bold"), width=120, height=50)
my_list.pack(pady=40)

# Insert
#my_list.insert(END, a)

# Create binding on the entry box call a function if release the key
my_entry.bind("<Key-Return>", check)

# Magnifying glass behavior
searchIcon = PhotoImage(file = 'Magnifying Glass.png')
label = ttk.Label(root, image =  searchIcon)
PhotoImage(file = 'Magnifying Glass.png')

d=my_entry.get()



isActive = False
def leave(e):
    isActive = True
    label.place(x = 32232, y=12323)
    
#my_entry.bind("<Leave>", stay)
my_entry.bind("<Enter>", leave)
    

label.place(x=102, y=82.75)


#myLabel.pack(side="bottom")
root.mainloop()

# %%
from tkinter import font
# Out:
# there's a match because FCUequals fcu
# there's a match because EFequals ef

# %%
from tkinter import *
from PIL import ImageTk, Image
import tkinter as ttk
from tkinter import font

# A should get what is in the search bar
root = Tk()
root.title('JCI Search')
root.iconbitmap('JCI Logo.ico')
root.geometry("500x500")

# Create a label
my_label = Label(root, text = "Search Acronyms", font = "Arial 20")
my_label.pack(pady=20)

# Create an entrybox
my_entry = Entry(root, font=("Helvetica", 20))

my_entry.grid_size()
my_entry.pack()

my_entry.bbox

# Create function to check entry vs list
def check(e):
    a = " "+my_entry.get()
    definitions = {
    "fcu": ["Fan Coil Unit (FCU)", "Fan Coil Unit             (FCU): Small terminal unit that uses a heat exchanger and a fan to generate heating or cooling for a space."],
    "ef": ["Exhaust Fan (EF)", "Exhaust Fan               (EF): Removes unpleasant odors like steam or smoke from rooms and reduces mold."],
    "uh": ["Unit Heater (UH)", "Unit Heater               (UH):  A unit heater has a heating element, a blower fan, and a heat exchanger that is designed to warm a space."],
    "dhw": ["Domestic Hot Water System (DHW)", "Domestic Hot Water System (DHW): Delivers hot water to people at sinks, tubs, and other areas that humans interact."],
    "sump": ["Unknown (SUMP)", "Unknown"],
    "misc": ["Unknwon (MISC)", "Unknown"]
    }

    summaries = {
        "fcu": 
        "Fan Coil Unit             (FCU): Small terminal unit that uses a heat exchanger and a fan to generate heating or cooling for a space.",
        "ef": 
        "Exhaust Fan               (EF): Removes unpleasant odors like steam or smoke from rooms and reduces mold.",
        "uh":
        "Unit Heater               (UH):  A unit heater has a heating element, a blower fan, and a heat exchanger that is designed to warm a space.",
        "dhw":
        "Domestic Hot Water System (DHW): Delivers hot water to people at sinks, tubs, and other areas that humans interact.",
        "sump":
        "Unknown                  (SUMP): DEF",
        "misc":
        "Unknwon                  (MISC): DEF"
        
    }
    
    # Sample sentence
    a = a.replace(".", "")
    
    # Split the sentence into words
    words = a.split()
    
    # Replace words with their definitions
    new_sentence = ' '.join([definitions.get(word.lower(), definitions[word][0]) for word in words])
    my_list.delete(0,END)
    my_list.insert(END, "TRANSLATIONS")
    my_list.insert(END, new_sentence)
    my_list.insert(END, "")
    my_list.insert(END, "SUMMARIES")
    # feed all entries to a string that stores the entries and insert that strsing into the

    # do not summarize duplicate
    for i in words:
        for j in summaries:
            if(i.lower() == j):
                my_list.insert(END, definitions.get(j, definitions[j][1]))
    #new_summary = ' '.join([summaries.get(s.lower(), s) for s in words])



# Create a Translator
my_list = Listbox(root, font=("Helvetica", 10, "bold"), width=120, height=50)
my_list.pack(pady=40)

# Insert
#my_list.insert(END, a)

# Create binding on the entry box call a function if release the key
my_entry.bind("<Key-Return>", check)

# Magnifying glass behavior
searchIcon = PhotoImage(file = 'Magnifying Glass.png')
label = ttk.Label(root, image =  searchIcon)
PhotoImage(file = 'Magnifying Glass.png')

d=my_entry.get()



isActive = False
def leave(e):
    isActive = True
    label.place(x = 32232, y=12323)
    
#my_entry.bind("<Leave>", stay)
my_entry.bind("<Enter>", leave)
    

label.place(x=102, y=82.75)


#myLabel.pack(side="bottom")
root.mainloop()

# %%
from tkinter import *
from PIL import ImageTk, Image
import tkinter as ttk
from tkinter import font

# A should get what is in the search bar
root = Tk()
root.title('JCI Search')
root.iconbitmap('JCI Logo.ico')
root.geometry("500x500")

# Create a label
my_label = Label(root, text = "Search Acronyms", font = "Arial 20")
my_label.pack(pady=20)

# Create an entrybox
my_entry = Entry(root, font=("Helvetica", 20))

my_entry.grid_size()
my_entry.pack()

my_entry.bbox



# Create function to check entry vs list
def check(e):
    
    a = my_entry.get()
    definitions = {
    "fcu": "Fan Coil Unit (FCU)",
    "ef": "Exhaust Fan (EF)",
    "uh": "Unit Heater (UH)",
    "dhw": "Domestic Hot Water System (DHW)",
    "sump": "Unknown (SUMP)",
    "misc": "Unknwon (MISC)"
    }

    summaries = {
        "fcu": 
        "Fan Coil Unit             (FCU): Small terminal unit that uses a heat exchanger and a fan to generate heating or cooling for a space.",
        "ef": 
        "Exhaust Fan               (EF): Removes unpleasant odors like steam or smoke from rooms and reduces mold.",
        "uh":
        "Unit Heater               (UH):  A unit heater has a heating element, a blower fan, and a heat exchanger that is designed to warm a space.",
        "dhw":
        "Domestic Hot Water System (DHW): Delivers hot water to people at sinks, tubs, and other areas that humans interact.",
        "sump":
        "Unknown                  (SUMP): DEF",
        "misc":
        "Unknwon                  (MISC): DEF"
        
    }
    isprint_all = a.lower() == "all"
    
    
    # Sample sentence
    a = a.replace(".", "")
    
    # Split the sentence into words
    words = a.split()
    
    # Replace words with their definitions
    new_sentence = ' '.join([definitions.get(word.lower(), word) for word in words])
    my_list.delete(0,END)
    my_list.insert(END, "TRANSLATIONS")
    my_list.insert(END, new_sentence)
    my_list.insert(END, "")
    my_list.insert(END, "SUMMARIES")

    my_set = []
    # feed all entries to a string that stores the entries and insert that strsing into the
    for i in words:
        for j in summaries:
            if((i.lower() == j and j not in my_set) or isprint_all):
                my_list.insert(END, summaries.get(j, j))
                my_set.append(j)
    #new_summary = ' '.join([summaries.get(s.lower(), s) for s in words])



# Create a Translator
my_list = Listbox(root, font=("Helvetica", 10, "bold"), width=160, height=50)
my_list.pack(pady=40)

# Insert
#my_list.insert(END, a)

# Create binding on the entry box call a function if release the key
my_entry.bind("<Key-Return>", check)

# Magnifying glass behavior
searchIcon = PhotoImage(file = 'Magnifying Glass.png')
label = ttk.Label(root, image =  searchIcon)
PhotoImage(file = 'Magnifying Glass.png')

d=my_entry.get()

isActive = False
def leave(e):
    isActive = True
    label.place(x = 32232, y=12323)
    
#my_entry.bind("<Leave>", stay)
my_entry.bind("<Enter>", leave)
    

label.place(x=102, y=82.75)


#myLabel.pack(side="bottom")
root.mainloop()
